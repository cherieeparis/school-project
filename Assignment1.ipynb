# %%
# Part A

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
# Q1 Read file
df = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv")

# %%
# Q2 Display the first five rows of the data
df.head(5)
# Out:
#             rownames   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
# Q3 Calculate the average of the mpg column for all cars within each category of the cyl column
df.groupby('cyl')[['mpg']].mean()
# Out:
#            mpg
# cyl
# 4    26.663636
# 6    19.742857
# 8    15.100000

# %%
# Q4 Create a histogram using the mpg column
df.hist(column = 'mpg')
# Out:
# array([[<Axes: title={'center': 'mpg'}>]], dtype=object)

# %%
# Q5 Choose two variables in the data and create a scatterplot
sns.scatterplot(x='mpg', y='disp', data=df)
# Out:
# <Axes: xlabel='mpg', ylabel='disp'>

# %%
# Part B

# %%
# Dataset resource : https://www.kaggle.com/datasets/sauravmishraa/frauddataset?resource=download
# this dataset provided the bank fraud transaction which allowed us to predict the future fraud activity to aviod it happen.

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
# import tidy data set
df = pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/3650114/6339987/fraud_dataset.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230917%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230917T215359Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")

# %%
# Q2 Display the first five rows of the data
df.head(5)
# Out:
#    transaction_id  transaction_amount       location  merchant  age gender  \
# 0               1              1000.0       New York  ABC Corp   35      M
# 1               2               500.0        Chicago   XYZ Inc   45      F
# 2               3              2000.0    Los Angeles  ABC Corp   28      M
# 3               4              1500.0  San Francisco   XYZ Inc   30      F
# 4               5               800.0        Chicago  ABC Corp   50      F
#
#    fraud_label
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0

# %%
# create a visualization using one (or two) variables from this data
sns.boxplot(x='location', y='transaction_amount', hue='gender', data=df).set(title='fraud amount by area')
# Out:
# [Text(0.5, 1.0, 'fraud amount by area')]
